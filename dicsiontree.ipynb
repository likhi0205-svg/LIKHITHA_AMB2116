# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("Social_Network_Ads.csv")
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
x= df.iloc[:,[2,3]].values
y= df.iloc[:,4].values

# %%
print(df.columns[[2,3]])
# Out:
# Index(['Age', 'EstimatedSalary'], dtype='object')

# %%
print(df.columns[4])
# Out:
# Purchased

# %%
from sklearn.model_selection import train_test_split
x_train,y_train,y_train,y_test = train_test_split(x,y,test_size = 0.25,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_x =StandardScaler()
x_train = sc_x.fit_transform(x_train)
x_test = sc_x.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 sc_x =StandardScaler()
#       3 x_train = sc_x.fit_transform(x_train)
# ----> 4 x_test = sc_x.transform(x_test)
#
# NameError: name 'x_test' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion="entropy",max_depth=None,min_samples_split=5,min_samples_leaf=2)

# %%
model.fit(x_train, y_train)
print(model)

# %%
y_pred_dec = model.predict(x_test)
y_pred_dec

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred_dec)
print(cm)

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(x_train,y_train)
y_pred_nb = nb.predict(x_test)
cmnb = confusion_matrix(y_test, y_pred_nb)
print(cmnb)	
accuracy_nb = accuracy_score(y_etst, y_pred_nb)
print("Accuracy:", accuracy_nb)

# %% [markdown]
# support vector mission(svm)=regression and classification

# %%
from sklearn.svm import SVC  #svc=classification  #scr = regression


#model = svc(kernel="rbf",c=1.0,gamma="scale", random_state=0)
#mode= SVC(kernel="linear")#hyperparameter
model = SVC(kernel = "poly",degree=3)
#model =SVC(kernel="rbf")
#training the model
model.fit(x_train,y_train)
print(model)
# Out:
# SVC(kernel='poly')

# %%
#predicting the test set results
y_pred_svm = model.predict(X_Test)
print(y_pred_svm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 #predicting the test set results
# ----> 2 y_pred_svm = model.predict(X_Test)
#       3 print(y_pred_svm)
#
# NameError: name 'X_Test' is not defined

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
cm_svc = confusion_matrix(y_test,y_pred_svm)
print(cm_svc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 #confusion matrix
#       2 from sklearn.metrics import confusion_matrix
# ----> 3 cm_svc = confusion_matrix(y_test,y_pred_svm)
#       4 print(cm_svc)
#
# NameError: name 'y_pred_svm' is not defined

# %%
#accuracy
from sklearn.metrics import accuracy_score
print("svm",accuracy_score(y_test,y_pred_svm))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 #accuracy
#       2 from sklearn.metrics import accuracy_score
# ----> 3 print("svm",accuracy_score(y_test,y_pred_svm))
#
# NameError: name 'y_pred_svm' is not defined
