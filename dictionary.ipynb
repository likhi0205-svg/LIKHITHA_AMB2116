# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("total elements:",len(CGPA))
# Out:
# total elements: 8

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("type of object:",type(CGPA))
# Out:
# type of object: <class 'dict'>

# %% [markdown]
# Access the elements in dictionary

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("\nCGPA of 4:",CGPA[4])  # key present
# Out:
# CGPA of 4: 6.9

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("\nCGPA of 9:",CGPA[9])   # key is not present
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
# ----> 2 print("\nCGPA of 9:",CGPA[9])
#
# KeyError: 9

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("CGPA of 8:",CGPA[8])
# Out:
# CGPA of 8: 8.5

# %% [markdown]
# #Traverse in dictionary

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
for k in CGPA:
    print("CGPA of ",k,":",CGPA[k])
# Out:
# CGPA of  1 : 5.7
# CGPA of  2 : 5.8
# CGPA of  3 : 6.6
# CGPA of  4 : 6.9
# CGPA of  5 : 5.4
# CGPA of  6 : 7.7
# CGPA of  7 : 8.9
# CGPA of  8 : 8.5

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
for k in CGPA:
    print("CGPA of ",k,"--> \n",CGPA[k])
# Out:
# CGPA of  1 -->
#  5.7
# CGPA of  2 -->
#  5.8
# CGPA of  3 -->
#  6.6
# CGPA of  4 -->
#  6.9
# CGPA of  5 -->
#  5.4
# CGPA of  6 -->
#  7.7
# CGPA of  7 -->
#  8.9
# CGPA of  8 -->
#  8.5

# %% [markdown]
# #Getting keys and values separetly

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("\n key :",CGPA.keys())
print("\n values :",CGPA.values())
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  key : dict_keys([1, 2, 3, 4, 5, 6, 7, 8])
#
#  values : dict_values([5.7, 5.8, 6.6, 6.9, 5.4, 7.7, 8.9, 8.5])

# %% [markdown]
# #Adding elements to dictionary

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
CGPA[9] = 9.9
print("\n after adding(9)  : " ,CGPA)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  after adding(9)  :  {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5, 9: 9.9}

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
CGPA[3] = 9.9
print(" after adding(3)  : " ,CGPA)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#  after adding(3)  :  {1: 5.7, 2: 5.8, 3: 9.9, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
CGPA[2] = 4.5
print("\n after adding(2)  : " ,CGPA)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  after adding(2)  :  {1: 5.7, 2: 4.5, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
CGPA[9] = 9.9
print("\n after adding(9)  : " ,CGPA)
CGPA[3] = 9.9
print("\n after adding(3)  :", CGPA)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  after adding(9)  :  {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5, 9: 9.9}
#
#  after adding(3)  : {1: 5.7, 2: 5.8, 3: 9.9, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5, 9: 9.9}

# %% [markdown]
# #UPDATING

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
CGPA[1] = 9.9
print("\n after updating(9)  : " ,CGPA)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  after updating(9)  :  {1: 9.9, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}

# %% [markdown]
# #DELETING

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
del CGPA[2]
print("\n after deleting(2) :", CGPA)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  after deleting(2) : {1: 5.7, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
del CGPA
print("\n after deleting :", CGPA)
#delete complete dictionary elements
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       2 print("dictionary -->",CGPA)
#       3 del CGPA
# ----> 4 print("\n after deleting :", CGPA)
#       5 #delete complete dictionary elements
#
# NameError: name 'CGPA' is not defined

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("type of object :",type( CGPA))
CGPA.clear()
print("\n after clearing :", CGPA)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
# type of object : <class 'dict'>
#
#  after clearing : {}

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)

s = 0
for i in CGPA:
    s = s+ CGPA[i]

print("\n sum :",s)
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  sum : 55.5

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)

s = 0
for i in CGPA:
    s = s+ CGPA[i]

print("\n sum :",s)
print("\n average :", s/len(CGPA))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  sum : 55.5
#
#  average : 6.9375

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)

s = 0
for i in CGPA:
    s = s+ CGPA[i]

print("\n sum :",s)
print("\n average :", s//len(CGPA))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  sum : 55.5
#
#  average : 6.0

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("sum :",sum(CGPA.values()))
print("average :", sum(CGPA.values())/len(CGPA))
print("average :", sum(CGPA.values())//len(CGPA))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
# sum : 55.5
# average : 6.9375
# average : 6.0

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("minimum value :",min(CGPA.values()))
print("maximum value :",max(CGPA.values()))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
# minimum value : 5.4
# maximum value : 8.9

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
for i in CGPA:

    
print("minimum value :",min(CGPA.keys()))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 print("dictionary -->",CGPA)
#       3 for i in CGPA:
# ----> 4     i=min(CGPA.values)
#       6 print("minimum value :",min(CGPA.keys()))
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("\n items :",(CGPA.items()))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  items : dict_items([(1, 5.7), (2, 5.8), (3, 6.6), (4, 6.9), (5, 5.4), (6, 7.7), (7, 8.9), (8, 8.5)])

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("\n items :",(list(CGPA.items())))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  items : [(1, 5.7), (2, 5.8), (3, 6.6), (4, 6.9), (5, 5.4), (6, 7.7), (7, 8.9), (8, 8.5)]

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("\n keys :",(list(CGPA.keys())))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  keys : [1, 2, 3, 4, 5, 6, 7, 8]

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("\n values:",(list(CGPA.values())))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  values: [5.7, 5.8, 6.6, 6.9, 5.4, 7.7, 8.9, 8.5]

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("\n keys :",(CGPA.keys()))
print("\n values:",(CGPA.values()))
print("\n items :",(CGPA.items()))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  keys : dict_keys([1, 2, 3, 4, 5, 6, 7, 8])
#
#  values: dict_values([5.7, 5.8, 6.6, 6.9, 5.4, 7.7, 8.9, 8.5])
#
#  items : dict_items([(1, 5.7), (2, 5.8), (3, 6.6), (4, 6.9), (5, 5.4), (6, 7.7), (7, 8.9), (8, 8.5)])

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("minimum value :",min(CGPA.values()))
print("maximum value :",max(CGPA.values()))
#method to find a key for min value
keylist = list(CGPA.keys())
vallist = list(CGPA.values())
minval = min(CGPA.values())
print("\n value = ",minval,"key -->",keylist[vallist.index(minval)])
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
# minimum value : 5.4
# maximum value : 8.9
#
#  value =  5.4 key --> 5

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("minimum value :",min(CGPA.values()))
print("maximum value :",max(CGPA.values()))
#method to find a key for max value(1)
keylist = list(CGPA.keys())
vallist = list(CGPA.values())
maxval = max(CGPA.values())
print("\n value = ",maxval,"key -->",keylist[vallist.index(maxval)])
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
# minimum value : 5.4
# maximum value : 8.9
#
#  value =  8.9 key --> 7

# %%
#method to find a key for max value(2)
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print("\n key having maximum value :", max(CGPA,key = CGPA.get))
print("\n key having minimum value :", min(CGPA,key = CGPA.get))
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#
#  key having maximum value : 7
#
#  key having minimum value : 5

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print(" is key 2 present-->",2 in CGPA.keys())
print(" is key 9 present-->",9 in CGPA.keys())
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#  is key 2 present--> True
#  is key 9 present--> False

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9,5:5.4,6:7.7,7:8.9,8:8.5}
print("dictionary -->",CGPA)
print(" is value 4.5 present-->",4.5 in CGPA.values())
print(" is value 1.1 present-->",1.1 not in CGPA.values())
print(" is value 1.1 present-->",1.1 in CGPA.values())
# Out:
# dictionary --> {1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9, 5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5}
#  is value 4.5 present--> False
#  is value 1.1 present--> True
#  is value 1.1 present--> False

# %% [markdown]
# merging the dictionary

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9}
CGPA1 = { 5:5.4,6:7.7,7:8.9,8:8.5}
CGPA1.update(CGPA)
print("\n CGPA1 after update :", CGPA1)
# Out:
#  CGPA1 after update : {5: 5.4, 6: 7.7, 7: 8.9, 8: 8.5, 1: 5.7, 2: 5.8, 3: 6.6, 4: 6.9}

# %%
CGPA ={1:5.7,2:5.8,3:6.6,4:6.9}
CGPA1 = { 5:5.4,3:7.7,7:8.9,8:8.5}
CGPA1.update(CGPA)
print("\n CGPA1 after update :", CGPA1)
# Out:
#  CGPA1 after update : {5: 5.4, 3: 6.6, 7: 8.9, 8: 8.5, 1: 5.7, 2: 5.8, 4: 6.9}

# %%
list1 = [1,2,3,4,5]
list2 = [6,7,8,9]
list1.append(list2)
print(" added list: ",list1)
# Out:
#  added list:  [1, 2, 3, 4, 5, [6, 7, 8, 9]]

# %% [markdown]
# cretae dictionary named car

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary:", cars)
# Out:
# dictionary: {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary:", cars)
cars["color"] =" red"
print("\n dictionary after adding  :", cars)
# Out:
# dictionary: {'brand': 'ford', 'model': 'mustang', 'year': 1964}
#
#  dictionary after adding  : {'brand': 'ford', 'model': 'mustang', 'year': 1964, 'color': ' red'}

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary:", cars)
cars["color"] =" red"
print("\n dictionary after adding  :", cars)
print("\n keys :", cars.keys())
print("\n values :", cars.values())
print("\n items :", cars.items())
# Out:
# dictionary: {'brand': 'ford', 'model': 'mustang', 'year': 1964}
#
#  dictionary after adding  : {'brand': 'ford', 'model': 'mustang', 'year': 1964, 'color': ' red'}
#
#  keys : dict_keys(['brand', 'model', 'year', 'color'])
#
#  values : dict_values(['ford', 'mustang', 1964, ' red'])
#
#  items : dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964), ('color', ' red')])

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary:", cars)
print("\n is model present in cars  :", "model"in cars.keys())
# Out:
# dictionary: {'brand': 'ford', 'model': 'mustang', 'year': 1964}
#
#  is model present in cars  : True

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary:", cars)
print("\n is color present in cars  :", "color"in cars.keys())
print("\n is color present in cars  :", "color" not in cars.keys())
# Out:
# dictionary: {'brand': 'ford', 'model': 'mustang', 'year': 1964}
#
#  is color present in cars  : False
#
#  is color present in cars  : True

# %%
cars={"brand":"ford","model":"mustang","year":1964}
print("dictionary:", cars)
print("\n is ford present in cars  :", "ford"in cars.keys())
# Out:
# dictionary: {'brand': 'ford', 'model': 'mustang', 'year': 1964}
#
#  is ford present in cars  : False

# %% [markdown]
# # Create a dictionary from two list

# %%
keys =['movie','hero','heroin','release_year']
values = ['toxic','yash','kiara',2026]
for i in range(len(keys)):
     mdict[keys[i]]=values[i]
print(mdict)
# Out:
# {'release_year': 2026, 'movie': 'toxic', 'hero': 'yash', 'heroin': 'kiara'}

# %%
dict1={'name':'jhon',10:[2,4,3]}
dict2=dict1
print(dict1)
print(dict2)
print()
# Out:
# {'name': 'jhon', 10: [2, 4, 3]}
# {'name': 'jhon', 10: [2, 4, 3]}

# %%
dict1={'name':'jhon',10:[2,4,3]}
dict2=dict1
print(dict1)
print(dict2)
print("after changing")
dict1.popitems()
print()
print(dict1)
print(dict2)
print()
# Out:
# {'name': 'jhon', 10: [2, 4, 3]}
# {'name': 'jhon', 10: [2, 4, 3]}
# after changing
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 6
#       4 print(dict2)
#       5 print("after changing")
# ----> 6 dict1.popitems()
#       7 print()
#       8 print(dict1)
#
# AttributeError: 'dict' object has no attribute 'popitems'

# %%
dict={'rice':120,'wheat':85,'maize':60}
print("dictionary :",dict)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60}

# %%
dict={'rice':120,'wheat':85,'maize':60}
print("dictionary :",dict)
print("number of crops grown :", len(dict))
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60}
# number of crops grown : 3

# %%
dict={'rice':120,'wheat':85,'maize':60}
print("dictionary :",dict)
print("yield of wheat :",dict['wheat'])
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60}
# yield of wheat : 85

# %%
dict={'rice':120,'wheat':85,'maize':60}
print("dictionary :",dict)
print("yield of wheat :", dict.get('wheat'))
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60}
# yield of wheat : 85

# %%
dict={'rice':120,'wheat':85,'maize':60}
print("dictionary :",dict)
dict['pulses']=45
print("after adding the crop :",dict)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60}
# after adding the crop : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
dict['rice']=130
print("after updation :",dict)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# after updation : {'rice': 130, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
print("all crops cultivated :",dict.keys())
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# all crops cultivated : dict_keys(['rice', 'wheat', 'maize', 'pulses'])

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
print("all crops yield :", dict.values())
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# all crops yield : dict_values([120, 85, 60, 45])

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
print("sugarcane present :", 'sugarcane' in dict.keys())
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# sugarcane present : False

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
dict['wheat']=dict['wheat']+10
print("after increase in yield :", dict)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# after increase in yield : {'rice': 120, 'wheat': 95, 'maize': 60, 'pulses': 45}

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
print("total yield :",sum(dict.values()))
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# total yield : 310

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
for k in dict:
    print("yield of crop",k,"is",dict[k])
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# yield of crop rice is 120
# yield of crop wheat is 85
# yield of crop maize is 60
# yield of crop pulses is 45

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
dict1=dict
print("dictionary1 :",dict1)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# dictionary1 : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
dict1=dict
print("dictionary1 :",dict1)
del dict1
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# dictionary1 : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
dict1=dict
print("dictionary1 :",dict1)
del dict1
print(dict1)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# dictionary1 : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 6
#       4 print("dictionary1 :",dict1)
#       5 del dict1
# ----> 6 print(dict1)
#
# NameError: name 'dict1' is not defined

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
for k,v in dict.items():
    print(k,"-->",v)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# rice --> 120
# wheat --> 85
# maize --> 60
# pulses --> 45

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
dict1=dict.copy()
print(dict1)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
dict1=dict.copy()
print(dict1)
del dict1
print(dict1)
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 6
#       4 print(dict1)
#       5 del dict1
# ----> 6 print(dict1)
#
# NameError: name 'dict1' is not defined

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
print("yield of jowar :", dict['jowar'])
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 3
#       1 dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
#       2 print("dictionary :",dict)
# ----> 3 print("yield of jowar :", dict['jowar'])
#
# KeyError: 'jowar'

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
if'jowar' in dict:
    print("present")
else:
    print("absent")
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# absent

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
print('jowar yield:',dict.get('jowar','not cultivated'))
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# jowar yield: not cultivated

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
dict.pop('maize')
dict.pop('maize')
# Out:
# dictionary : {'rice': 120, 'wheat': 85, 'maize': 60, 'pulses': 45}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 4
#       2 print("dictionary :",dict)
#       3 dict.pop('maize')
# ----> 4 dict.pop('maize')
#
# KeyError: 'maize'

# %%
dict={'rice':120,'wheat':85,'maize':60,'pulses':45}
print("dictionary :",dict)
del dict('maize')
# Out:
#   Cell In[45], line 3
#     del dict('maize')
#         ^
# SyntaxError: cannot delete function call
