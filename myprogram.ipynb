# %%
fish_type=0
cost=0
fish_dict={'catla':26,'rohu':34,'jilabi':54}

# %%
import random
random.randint(1,10)
# Out:
# 9

# %%
numbers=[1,2,3,4,5,6,7]
print(random.sample(numbers,3))
# Out:
# [4, 6, 2]

# %% [markdown]
# money=45
# print(f" I have ${money}")

# %% [markdown]
# fish game

# %%
inventary={}
total_money=0
fish_prives={
    'rohu':34,
    'catla':45,
    'jilabi':32
}
print("\n  Fishing Game Menu   ")
print("1.catch fish")
print("2.view inventory")
print("3.sell fish")
print("4.exit")
while True:
    choice =int(input("choose an option"))
if choice==1:
    fish=random.choice(list(fish_price.keys()))
    inventory[fish]=inventory.get(fish,0)+1
    print(f" you caught a{fish}")
elif choice==2:
    if inventory=={}:
         print("no fish")
  else:
       print("your inventory:")
       for fish,count in inventory.items():
           print(f"{fish}:{count}")
elif choice==3:
    if inventory=={}:
        print("no fish to sell")
  else:
       earnings=0
       for fish ,count in inventory.items():
           earnings+=fish_price[fish]*count
       total_money+=earnings
       inventory.clear()
       print(f"you sold all fish for ${earnings}")
elif choice==4:
   print(f"final money earned: ${total_money}")
   print("thanks for playing")
   break
else:
   print("invalid choice...Try again")
# Out:
#   File <string>:22
#     else:
#          ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# Math function

# %%
import math as m   #exponential function
print("exp(-200 :",m.exp(-200))
# Out:
# exp(-200 : 1.3838965267367376e-87

# %%
print("log (100,2) :",m.log(100,2))  #log function
# Out:
# log (100,2) : 6.643856189774725

# %%
print("log (100,10) :",m.log(100,10))
# Out:
# log (100,10) : 2.0

# %%
print("log10 (100) :",m.log10(100))
# Out:
# log10 (100) : 2.0

# %%
print("m.cos(30) :", m.cos(30)) #cos function
# Out:
# m.cos(30) : 0.15425144988758405

# %%
print("m.sin(30) :", m.sin(30))
# Out:
# m.sin(30) : -0.9880316240928618

# %%
print("m.tan(30) :", m.tan(30))
# Out:
# m.tan(30) : -6.405331196646276

# %%
print("square root of 144 :", m.sqrt(144))
# Out:
# square root of 144 : 12.0

# %%
print("m.ceil(45.5) :", m.ceil(45.5))  #roundoff to upper number
# Out:
# m.ceil(45.5) : 46

# %%
print("m.floor(45.5) :", m.floor(45.5)) #round off to lower number
# Out:
# m.floor(45.5) : 45

# %% [markdown]
# def function

# %%
def sumfn(m,n):
  add= m+n
  print(add)
m=12
n=14
sumfn(m,n)
# Out:
# 26

# %%
m=12
n=14
sum fn(m,n)
# Out:
#   Cell In[58], line 3
#     sum fn(m,n)
#         ^
# SyntaxError: invalid syntax

# %%
def sumfn(m,n):
  add= m+n
  
m=12
n=14
c=sumfn(m,n)
print(c)
# Out:
# None

# %%
def sumfn():
    m=23
    n=34
    add=m+n 
print(add)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 5
#       3     n=34
#       4     add=m+n
# ----> 5 print(add)
#
# NameError: name 'add' is not defined

# %%
def sumfn():
    m=23
    n=34
    add=m+n
c=sumfn()
print(c)
# Out:
# None

# %%
def max(n1,n2):
  
  if n1>n2:
     result=n1
  else:
    result=n2
  return result
z =max(23,32)
print(z)
# Out:
# 32

# %%
import math as m
print(m.factorial(8))
# Out:
# 40320

# %%
sum=0
n=int(input("enter a number"))
for i in range(1,n+1):
    sum=sum+1
    print(sum)
# Out:
# enter a number 3
# 1
# 2
# 3

# %%
factorial=1
n=int(input("enter a number"))
for i in range(1,n+1):
    factorial=factorial*i
print(factorial)
# Out:
# enter a number 4
# 24

# %%
#with paramete and without return type
# outside function read the input,print output inside the function
def fact(m):
     fact=1
     if (m>0):
         for i in range (1,m+1):
             fact=fact*i
         print("factorial of ",m,"is",fact)
     else:
         print("enter a valid number")
n =int(input("enter a numbera"))
fact(n)
# Out:
# enter a numbera 5
# factorial of  5 is 120

# %%
#with parameter and with return type
#print outside the function
def fact(m):
     fact=1
     if (m>0):
         for i in range (1,m+1):
             fact=fact*i
         return fact    # by return the fuction
     else:
         print("enter a valid number")
n =int(input("enter a numbera"))
z=fact(n)
print(z)    # to print the output as z
# Out:
# enter a numbera 5
# 120

# %%
#without parameter and without return type

def fact():  # without parameter
     m =int(input("enter a numbera"))
     fact=1
     if (m>0):
         for i in range (1,m+1):
             fact=fact*i
         print("factorial of ",m,"is",fact) #without return type
     else:
         print("enter a valid number")

fact()  #without parameter
# Out:
# enter a numbera 4
# factorial of  4 is 24

# %%
#without parameter and with return type

def fact():  # without parameter
     m =int(input("enter a numbera"))
     fact=1
     if (m>0):
         for i in range (1,m+1):
             fact=fact*i
         return fact #with return type
     else:
         print("enter a valid number")

z=fact()  #without parameter
print(z)
# Out:
# enter a numbera 4
# 24

# %%
#scope of the variables
def func(x):
    print("local x is:",x)
    x=2
    print("change local x to",x)

x=48
func(x)
print(x)
# Out:
# local x is: 48
# change local x to 2
# 48

# %%
def func(x):
    print("local x is:",x)
    

x=48
func(x)
print(x)
# Out:
# local x is: 48
# 48

# %%
# global varibles
def func():
    global y
    print("y is :",y)
    y=3
    print("changed y to:",y)

y=34
func()
print(y)
# Out:
# y is : 34
# changed y to: 3
# 3

# %%
total=65
def sum(agr1,agr2):
    total=agr1+agr2
    print("inside the function local total:",total)
    return total

sum(32,65)
print("outside the function global total:",total)
# Out:
# inside the function local total: 97
# outside the function global total: 65

# %%
# required argument
def printme(x):
    print(x)

printme("hello")
printme(23.4)
printme(65)
# Out:
# hello
# 23.4
# 65

# %%
def printme(x):
    print(x)

printme("hello",23)
printme(23.4)
printme(65)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[120], line 4
#       1 def printme(x):
#       2     print(x)
# ----> 4 printme("hello",23)
#       5 printme(23.4)
#       6 printme(65)
#
# TypeError: printme() takes 1 positional argument but 2 were given

# %%
def printme(x,y):
    print(x,y)

printme("hello")
printme(23.4)
printme(65)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[121], line 4
#       1 def printme(x,y):
#       2     print(x,y)
# ----> 4 printme("hello")
#       5 printme(23.4)
#       6 printme(65)
#
# TypeError: printme() missing 1 required positional argument: 'y'

# %%
def printme(x,y):
    print(x,y)

printme("hello",34)
printme(23.4,"hi")
printme(65,34)
# Out:
# hello 34
# 23.4 hi
# 65 34

# %%
#keyward argument
def printme(x):
    print(x)
    return
    
printme("hello")
printme(x="my strings")
printme(65)
# Out:
# hello
# my strings
# 65

# %%
def printme(x):
    print(x)
    return
    
printme("hello")
printme(str="my strings")
printme(65)
# Out:
# hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[125], line 6
#       3     return
#       5 printme("hello")
# ----> 6 printme(str="my strings")
#       7 printme(65)
#
# TypeError: printme() got an unexpected keyword argument 'str'

# %%
def printme(x1):
    print(x)
    return
    
printme("hello")
printme(x="my strings")
printme(65)
# Out:
# 48
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[126], line 6
#       3     return
#       5 printme("hello")
# ----> 6 printme(x="my strings")
#       7 printme(65)
#
# TypeError: printme() got an unexpected keyword argument 'x'. Did you mean 'x1'?

# %%
#default argument
def func(a,b=3,c=5):
    print("a =",a,"b =",b,"c =",c)

func(3,4,6)
# Out:
# a = 3 b = 4 c = 6

# %%
def func(a,b=3,c=5):
    print("a =",a,"b =",b,"c =",c)

func(4,6)
# Out:
# a = 4 b = 6 c = 5

# %%
def func(a,b=3,c=5):
    print("a =",a,"b =",b,"c =",c)

func(0,4,0)
# Out:
# a = 0 b = 4 c = 0

# %%
def func(a,b=3,c=5):
    print("a =",a,"b =",b,"c =",c)

func(,4,)
# Out:
#   Cell In[135], line 4
#     func(,4,)
#          ^
# SyntaxError: invalid syntax

# %%
def func(a,b=3,c=5):
    print("a =",a,"b =",b,"c =",c)

func()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[136], line 4
#       1 def func(a,b=3,c=5):
#       2     print("a =",a,"b =",b,"c =",c)
# ----> 4 func()
#
# TypeError: func() missing 1 required positional argument: 'a'

# %%
def func(a,b=3,c=5):
    print("a =",a,"b =",b,"c =",c)

func(c=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[137], line 4
#       1 def func(a,b=3,c=5):
#       2     print("a =",a,"b =",b,"c =",c)
# ----> 4 func(c=4)
#
# TypeError: func() missing 1 required positional argument: 'a'

# %%
def func(a,b=3,c=5):
    print("a =",a,"b =",b,"c =",c)

func(c=3,a=4,b=6)
# Out:
# a = 4 b = 6 c = 3

# %%
#variable length argument
def check(name,*marks):
    print(name)
    print(marks)

check('likhi',23,34,45,56,67,77,889,9)
# Out:
# likhi
# (23, 34, 45, 56, 67, 77, 889, 9)

# %%
def check(name,*marks):
    print(name)
    print(marks)

check(23,34,45,56,67,77,889,9)
# Out:
# 23
# (34, 45, 56, 67, 77, 889, 9)

# %%
def check(name,*marks):
    print(name)
    print(marks)

check('likhi','i','r','t')
# Out:
# likhi
# ('i', 'r', 't')

# %%
def check(name,marks*):
    print(name)
    print(marks)

check('likhi',23,34,45,56,67,77,889,9)
# Out:
#   Cell In[142], line 1
#     def check(name,marks*):
#                         ^
# SyntaxError: invalid syntax

# %%
inventary={}
total_money=0
fish_prives={
    'rohu':34,
    'catla':45,
    'jilabi':32
}
def func():
    print("\n  Fishing Game Menu   ")
    print("1.catch fish")
    print("2.view inventory")
    print("3.sell fish")
    print("4.exit")
showmenu()
while True:
    showmenu()
    choice =int(input("choose an option"))
if choice==1:
    fish=random.choice(list(fish_price.keys()))
    inventory[fish]=inventory.get(fish,0)+1
    print(f" you caught a{fish}")
elif choice==2:
    if inventory=={}:
         print("no fish")
    else:
       print("your inventory:")
       for fish,count in inventory.items():
           print(f"{fish}:{count}")
elif choice==3:
    if inventory=={}:
        print("no fish to sell")
    else:
       earnings=0
       for fish ,count in inventory.items():
           earnings+=fish_price[fish]*count
       total_money+=earnings
       inventory.clear()
       print(f"you sold all fish for ${earnings}")
elif choice==4:
   print(f"final money earned: ${total_money}")
   print("thanks for playing")
   break
else:
        print("invalid choice...Try again")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 14
#      12     print("3.sell fish")
#      13     print("4.exit")
# ---> 14 showmenu()
#      15 while True:
#      16     showmenu()
#
# NameError: name 'showmenu' is not defined

# %%
inventary={}
total_money=0
fish_prices={
    'rohu':34,
    'catla':45,
    'jilabi':32
}
def showmenu():
    print("\n  Fishing Game Menu   ")
    print("1.catch fish")
    print("2.view inventory")
    print("3.sell fish")
    print("4.exit")
def catchfish():
    fish = random.choice(list(fish_prices.keys()))
    inventory[fish] = inventory.get(fish,0)+1
    print(f"you caught a {fish}")
showmenu()
while True:
    showmenu()
    choice =int(input("choose an option"))
if choice==1:
    fish=random.choice(list(fish_price.keys()))
    inventory[fish]=inventory.get(fish,0)+1
    print(f" you caught a{fish}")
elif choice==2:
    if inventory=={}:
         print("no fish")
    else:
       print("your inventory:")
       for fish,count in inventory.items():
           print(f"{fish}:{count}")
elif choice==3:
    if inventory=={}:
        print("no fish to sell")
    else:
       earnings=0
       for fish ,count in inventory.items():
           earnings+=fish_price[fish]*count
       total_money+=earnings
       inventory.clear()
       print(f"you sold all fish for ${earnings}")
elif choice==4:
   print(f"final money earned: ${total_money}")
   print("thanks for playing")
   break
else:
        print("invalid choice...Try again")
# Out:
#   Fishing Game Menu
# 1.catch fish
# 2.view inventory
# 3.sell fish
# 4.exit
#
#   Fishing Game Menu
# 1.catch fish
# 2.view inventory
# 3.sell fish
# 4.exit
# choose an option 1
#   Fishing Game Menu
# 1.catch fish
# 2.view inventory
# 3.sell fish
# 4.exit
# choose an option 2
#   Fishing Game Menu
# 1.catch fish
# 2.view inventory
# 3.sell fish
# 4.exit
